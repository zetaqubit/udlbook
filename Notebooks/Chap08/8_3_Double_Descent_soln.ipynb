# %% [markdown]
# <a href="https://colab.research.google.com/github/zetaqubit/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent_soln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 155 (delta 52), reused 123 (delta 26), pack-reused 0
# Receiving objects: 100% (155/155), 6.48 MiB | 3.29 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#  - around 4000 parameters
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#  - before 4000 parameters. Maybe 2000.
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#  - around 4000 parameters

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.298437, train error 88.80,  test loss 2.299133, test error 89.30
# Epoch   100, train loss 1.910106, train error 71.32,  test loss 1.748132, test error 69.40
# Epoch   200, train loss 1.887706, train error 70.15,  test loss 1.719262, test error 67.75
# Epoch   300, train loss 1.870883, train error 70.18,  test loss 1.707814, test error 68.03
# Epoch   400, train loss 1.864389, train error 69.30,  test loss 1.700800, test error 67.28
# Epoch   500, train loss 1.865192, train error 69.53,  test loss 1.705573, test error 67.20
# Epoch   600, train loss 1.866429, train error 70.32,  test loss 1.701072, test error 67.62
# Epoch   700, train loss 1.863800, train error 69.70,  test loss 1.697220, test error 67.32
# Epoch   800, train loss 1.863256, train error 70.20,  test loss 1.696408, test error 67.62
# Epoch   900, train loss 1.862366, train error 70.00,  test loss 1.702217, test error 67.35
# Training model with   4 hidden variables
# Epoch     0, train loss 2.165021, train error 80.78,  test loss 2.103780, test error 77.62
# Epoch   100, train loss 1.801466, train error 66.60,  test loss 1.667171, test error 65.47
# Epoch   200, train loss 1.794510, train error 65.90,  test loss 1.667667, test error 65.68
# Epoch   300, train loss 1.784658, train error 65.28,  test loss 1.659408, test error 64.28
# Epoch   400, train loss 1.780915, train error 64.10,  test loss 1.646655, test error 62.75
# Epoch   500, train loss 1.745517, train error 62.30,  test loss 1.617283, test error 61.10
# Epoch   600, train loss 1.743711, train error 61.88,  test loss 1.620994, test error 61.33
# Epoch   700, train loss 1.737341, train error 61.65,  test loss 1.611510, test error 61.60
# Epoch   800, train loss 1.742499, train error 62.15,  test loss 1.621103, test error 61.40
# Epoch   900, train loss 1.736390, train error 61.20,  test loss 1.608984, test error 60.83
# Training model with   6 hidden variables
# Epoch     0, train loss 2.157576, train error 80.30,  test loss 2.113716, test error 78.00
# Epoch   100, train loss 1.734312, train error 63.67,  test loss 1.547944, test error 60.47
# Epoch   200, train loss 1.677778, train error 59.28,  test loss 1.479533, test error 57.03
# Epoch   300, train loss 1.663589, train error 59.28,  test loss 1.471884, test error 57.25
# Epoch   400, train loss 1.654056, train error 59.47,  test loss 1.462882, test error 56.85
# Epoch   500, train loss 1.641854, train error 57.47,  test loss 1.451729, test error 55.30
# Epoch   600, train loss 1.640312, train error 58.12,  test loss 1.456239, test error 56.20
# Epoch   700, train loss 1.634796, train error 56.85,  test loss 1.455056, test error 54.97
# Epoch   800, train loss 1.634693, train error 57.30,  test loss 1.451271, test error 55.25
# Epoch   900, train loss 1.635202, train error 58.47,  test loss 1.446279, test error 55.50
# Training model with   8 hidden variables
# Epoch     0, train loss 2.269640, train error 86.35,  test loss 2.265866, test error 85.35
# Epoch   100, train loss 1.622774, train error 57.75,  test loss 1.447780, test error 56.33
# Epoch   200, train loss 1.575270, train error 55.38,  test loss 1.455090, test error 55.33
# Epoch   300, train loss 1.545758, train error 53.92,  test loss 1.438892, test error 54.38
# Epoch   400, train loss 1.541880, train error 54.28,  test loss 1.439896, test error 54.33
# Epoch   500, train loss 1.534579, train error 53.95,  test loss 1.452782, test error 54.05
# Epoch   600, train loss 1.529867, train error 53.88,  test loss 1.452333, test error 54.17
# Epoch   700, train loss 1.528701, train error 54.60,  test loss 1.454925, test error 54.70
# Epoch   800, train loss 1.528461, train error 53.85,  test loss 1.456857, test error 54.62
# Epoch   900, train loss 1.528469, train error 53.42,  test loss 1.457184, test error 55.05
# Training model with  10 hidden variables
# Epoch     0, train loss 2.209829, train error 84.12,  test loss 2.190282, test error 84.20
# Epoch   100, train loss 1.625151, train error 56.78,  test loss 1.466574, test error 56.65
# Epoch   200, train loss 1.519191, train error 52.12,  test loss 1.408198, test error 52.35
# Epoch   300, train loss 1.486140, train error 51.30,  test loss 1.386384, test error 51.38
# Epoch   400, train loss 1.479255, train error 50.28,  test loss 1.405138, test error 51.38
# Epoch   500, train loss 1.471378, train error 50.85,  test loss 1.408859, test error 51.38
# Epoch   600, train loss 1.456572, train error 49.58,  test loss 1.411481, test error 51.65
# Epoch   700, train loss 1.448607, train error 49.53,  test loss 1.413461, test error 51.45
# Epoch   800, train loss 1.435851, train error 48.95,  test loss 1.392790, test error 51.80
# Epoch   900, train loss 1.432472, train error 48.92,  test loss 1.392314, test error 51.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.226830, train error 83.35,  test loss 2.208696, test error 83.10
# Epoch   100, train loss 1.530992, train error 51.55,  test loss 1.469835, test error 55.60
# Epoch   200, train loss 1.435262, train error 48.90,  test loss 1.459528, test error 54.50
# Epoch   300, train loss 1.390521, train error 47.28,  test loss 1.469267, test error 54.05
# Epoch   400, train loss 1.364382, train error 46.28,  test loss 1.490663, test error 54.22
# Epoch   500, train loss 1.345150, train error 46.30,  test loss 1.523269, test error 56.03
# Epoch   600, train loss 1.330338, train error 45.80,  test loss 1.521420, test error 54.88
# Epoch   700, train loss 1.332336, train error 45.67,  test loss 1.546971, test error 54.90
# Epoch   800, train loss 1.314663, train error 44.90,  test loss 1.559540, test error 55.42
# Epoch   900, train loss 1.313589, train error 44.72,  test loss 1.565509, test error 54.95
# Training model with  18 hidden variables
# Epoch     0, train loss 2.222844, train error 82.88,  test loss 2.210293, test error 82.93
# Epoch   100, train loss 1.376601, train error 44.58,  test loss 1.316581, test error 47.75
# Epoch   200, train loss 1.285906, train error 41.72,  test loss 1.327834, test error 47.58
# Epoch   300, train loss 1.252921, train error 41.15,  test loss 1.358336, test error 48.72
# Epoch   400, train loss 1.233028, train error 40.28,  test loss 1.383129, test error 48.78
# Epoch   500, train loss 1.216889, train error 39.85,  test loss 1.404965, test error 49.30
# Epoch   600, train loss 1.181620, train error 38.62,  test loss 1.431058, test error 49.28
# Epoch   700, train loss 1.179439, train error 39.85,  test loss 1.473840, test error 49.70
# Epoch   800, train loss 1.174928, train error 39.30,  test loss 1.496632, test error 50.03
# Epoch   900, train loss 1.164120, train error 38.90,  test loss 1.502506, test error 49.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.197731, train error 80.47,  test loss 2.180593, test error 80.53
# Epoch   100, train loss 1.312819, train error 44.20,  test loss 1.371890, test error 51.70
# Epoch   200, train loss 1.179630, train error 40.55,  test loss 1.422027, test error 51.05
# Epoch   300, train loss 1.123565, train error 39.15,  test loss 1.479038, test error 52.17
# Epoch   400, train loss 1.093677, train error 37.45,  test loss 1.524178, test error 51.95
# Epoch   500, train loss 1.067358, train error 36.35,  test loss 1.582934, test error 53.03
# Epoch   600, train loss 1.047636, train error 35.55,  test loss 1.633927, test error 53.55
# Epoch   700, train loss 1.048517, train error 36.12,  test loss 1.720791, test error 53.20
# Epoch   800, train loss 1.025874, train error 35.70,  test loss 1.733142, test error 53.95
# Epoch   900, train loss 1.000804, train error 34.72,  test loss 1.792242, test error 53.10
# Training model with  26 hidden variables
# Epoch     0, train loss 2.130914, train error 79.80,  test loss 2.100620, test error 78.95
# Epoch   100, train loss 1.246723, train error 40.75,  test loss 1.381476, test error 51.25
# Epoch   200, train loss 1.104331, train error 37.10,  test loss 1.472545, test error 51.95
# Epoch   300, train loss 1.024738, train error 34.07,  test loss 1.585004, test error 52.70
# Epoch   400, train loss 0.966093, train error 32.32,  test loss 1.734553, test error 53.28
# Epoch   500, train loss 0.936500, train error 30.75,  test loss 1.845307, test error 54.12
# Epoch   600, train loss 0.902085, train error 30.20,  test loss 1.959324, test error 55.47
# Epoch   700, train loss 0.881994, train error 29.80,  test loss 2.043263, test error 54.65
# Epoch   800, train loss 0.868383, train error 29.78,  test loss 2.095243, test error 55.45
# Epoch   900, train loss 0.847279, train error 28.53,  test loss 2.133447, test error 55.25
# Training model with  30 hidden variables
# Epoch     0, train loss 2.174942, train error 81.68,  test loss 2.132489, test error 80.43
# Epoch   100, train loss 1.152048, train error 37.20,  test loss 1.317490, test error 49.00
# Epoch   200, train loss 0.978632, train error 31.85,  test loss 1.495642, test error 50.50
# Epoch   300, train loss 0.889441, train error 30.12,  test loss 1.693528, test error 52.88
# Epoch   400, train loss 0.820387, train error 27.65,  test loss 1.841068, test error 52.97
# Epoch   500, train loss 0.779928, train error 26.38,  test loss 1.997994, test error 53.30
# Epoch   600, train loss 0.749701, train error 25.55,  test loss 2.138425, test error 53.50
# Epoch   700, train loss 0.698448, train error 24.05,  test loss 2.317610, test error 53.90
# Epoch   800, train loss 0.678850, train error 23.82,  test loss 2.499297, test error 54.72
# Epoch   900, train loss 0.678136, train error 24.05,  test loss 2.634217, test error 55.08
# Training model with  35 hidden variables
# Epoch     0, train loss 2.182230, train error 79.60,  test loss 2.169324, test error 80.60
# Epoch   100, train loss 1.039757, train error 33.32,  test loss 1.339168, test error 48.22
# Epoch   200, train loss 0.825344, train error 26.85,  test loss 1.656660, test error 51.08
# Epoch   300, train loss 0.732800, train error 25.03,  test loss 1.995004, test error 53.22
# Epoch   400, train loss 0.642038, train error 21.68,  test loss 2.257206, test error 54.12
# Epoch   500, train loss 0.576889, train error 19.88,  test loss 2.505459, test error 54.45
# Epoch   600, train loss 0.541496, train error 18.30,  test loss 2.763803, test error 55.05
# Epoch   700, train loss 0.606255, train error 22.55,  test loss 3.082727, test error 55.58
# Epoch   800, train loss 0.492205, train error 16.90,  test loss 3.227187, test error 56.83
# Epoch   900, train loss 0.500721, train error 17.57,  test loss 3.469760, test error 56.78
# Training model with  40 hidden variables
# Epoch     0, train loss 2.120655, train error 77.40,  test loss 2.096380, test error 78.53
# Epoch   100, train loss 0.912713, train error 29.35,  test loss 1.500336, test error 51.28
# Epoch   200, train loss 0.648192, train error 20.50,  test loss 2.013193, test error 53.58
# Epoch   300, train loss 0.505805, train error 15.93,  test loss 2.626611, test error 54.75
# Epoch   400, train loss 0.432875, train error 14.18,  test loss 3.316768, test error 56.03
# Epoch   500, train loss 0.345974, train error 11.78,  test loss 3.958912, test error 55.90
# Epoch   600, train loss 0.329857, train error 10.97,  test loss 4.707108, test error 56.62
# Epoch   700, train loss 0.302240, train error 10.10,  test loss 5.466423, test error 57.53
# Epoch   800, train loss 0.261147, train error 9.35,  test loss 6.022757, test error 57.33
# Epoch   900, train loss 0.330851, train error 11.65,  test loss 6.838791, test error 58.50
# Training model with  45 hidden variables
# Epoch     0, train loss 2.089423, train error 77.38,  test loss 2.036004, test error 77.28
# Epoch   100, train loss 0.836829, train error 26.55,  test loss 1.586684, test error 51.97
# Epoch   200, train loss 0.507899, train error 16.45,  test loss 2.465699, test error 55.83
# Epoch   300, train loss 0.324223, train error 10.00,  test loss 3.556541, test error 56.90
# Epoch   400, train loss 0.249004, train error 8.53,  test loss 4.757900, test error 58.65
# Epoch   500, train loss 0.211728, train error 7.25,  test loss 5.906558, test error 57.85
# Epoch   600, train loss 0.200825, train error 7.47,  test loss 7.033989, test error 57.75
# Epoch   700, train loss 0.173521, train error 6.35,  test loss 8.259112, test error 58.42
# Epoch   800, train loss 0.195627, train error 6.70,  test loss 9.210532, test error 57.95
# Epoch   900, train loss 0.156173, train error 5.53,  test loss 10.113661, test error 59.17
# Training model with  50 hidden variables
# Epoch     0, train loss 2.113823, train error 78.45,  test loss 2.057245, test error 76.93
# Epoch   100, train loss 0.760664, train error 24.28,  test loss 1.630088, test error 51.95
# Epoch   200, train loss 0.355713, train error 10.68,  test loss 2.730073, test error 54.92
# Epoch   300, train loss 0.243160, train error 8.43,  test loss 4.210056, test error 55.53
# Epoch   400, train loss 0.097387, train error 2.57,  test loss 5.887219, test error 56.72
# Epoch   500, train loss 0.015432, train error 0.00,  test loss 7.104948, test error 56.30
# Epoch   600, train loss 0.009311, train error 0.00,  test loss 7.869962, test error 56.40
# Epoch   700, train loss 0.006425, train error 0.00,  test loss 8.425217, test error 56.55
# Epoch   800, train loss 0.004880, train error 0.00,  test loss 8.860194, test error 56.60
# Epoch   900, train loss 0.003903, train error 0.00,  test loss 9.212379, test error 56.58
# Training model with  55 hidden variables
# Epoch     0, train loss 2.051637, train error 76.50,  test loss 1.985821, test error 75.10
# Epoch   100, train loss 0.642554, train error 19.93,  test loss 1.642855, test error 50.95
# Epoch   200, train loss 0.239002, train error 6.57,  test loss 2.986264, test error 53.42
# Epoch   300, train loss 0.048645, train error 0.12,  test loss 4.704249, test error 54.60
# Epoch   400, train loss 0.014421, train error 0.00,  test loss 5.790689, test error 55.08
# Epoch   500, train loss 0.008375, train error 0.00,  test loss 6.427431, test error 55.45
# Epoch   600, train loss 0.005704, train error 0.00,  test loss 6.871687, test error 55.38
# Epoch   700, train loss 0.004214, train error 0.00,  test loss 7.227986, test error 55.62
# Epoch   800, train loss 0.003329, train error 0.00,  test loss 7.508806, test error 55.70
# Epoch   900, train loss 0.002745, train error 0.00,  test loss 7.751714, test error 55.62
# Training model with  60 hidden variables
# Epoch     0, train loss 2.047134, train error 75.12,  test loss 1.976390, test error 74.22
# Epoch   100, train loss 0.537740, train error 15.95,  test loss 1.861593, test error 51.40
# Epoch   200, train loss 0.101061, train error 0.88,  test loss 3.633636, test error 55.12
# Epoch   300, train loss 0.018055, train error 0.00,  test loss 5.029386, test error 56.08
# Epoch   400, train loss 0.008820, train error 0.00,  test loss 5.738077, test error 56.22
# Epoch   500, train loss 0.005661, train error 0.00,  test loss 6.202120, test error 56.42
# Epoch   600, train loss 0.004064, train error 0.00,  test loss 6.541924, test error 56.42
# Epoch   700, train loss 0.003132, train error 0.00,  test loss 6.813140, test error 56.58
# Epoch   800, train loss 0.002527, train error 0.00,  test loss 7.036873, test error 56.50
# Epoch   900, train loss 0.002099, train error 0.00,  test loss 7.226595, test error 56.47
# Training model with  70 hidden variables
# Epoch     0, train loss 2.040558, train error 74.88,  test loss 1.975657, test error 75.15
# Epoch   100, train loss 0.341180, train error 8.60,  test loss 1.917923, test error 51.47
# Epoch   200, train loss 0.030266, train error 0.00,  test loss 3.478528, test error 51.88
# Epoch   300, train loss 0.010440, train error 0.00,  test loss 4.215736, test error 51.97
# Epoch   400, train loss 0.005901, train error 0.00,  test loss 4.626271, test error 52.15
# Epoch   500, train loss 0.003971, train error 0.00,  test loss 4.916819, test error 51.95
# Epoch   600, train loss 0.002949, train error 0.00,  test loss 5.131819, test error 52.00
# Epoch   700, train loss 0.002319, train error 0.00,  test loss 5.313518, test error 51.95
# Epoch   800, train loss 0.001900, train error 0.00,  test loss 5.461725, test error 52.12
# Epoch   900, train loss 0.001601, train error 0.00,  test loss 5.591620, test error 52.15
# Training model with  80 hidden variables
# Epoch     0, train loss 2.004148, train error 73.72,  test loss 1.928575, test error 73.47
# Epoch   100, train loss 0.205137, train error 3.00,  test loss 2.191990, test error 52.58
# Epoch   200, train loss 0.019213, train error 0.00,  test loss 3.585402, test error 53.50
# Epoch   300, train loss 0.007861, train error 0.00,  test loss 4.145181, test error 53.35
# Epoch   400, train loss 0.004696, train error 0.00,  test loss 4.484951, test error 53.35
# Epoch   500, train loss 0.003254, train error 0.00,  test loss 4.727463, test error 53.53
# Epoch   600, train loss 0.002453, train error 0.00,  test loss 4.915265, test error 53.53
# Epoch   700, train loss 0.001949, train error 0.00,  test loss 5.068811, test error 53.55
# Epoch   800, train loss 0.001607, train error 0.00,  test loss 5.198578, test error 53.55
# Epoch   900, train loss 0.001359, train error 0.00,  test loss 5.311286, test error 53.55
# Training model with  90 hidden variables
# Epoch     0, train loss 2.028962, train error 75.25,  test loss 1.956799, test error 74.70
# Epoch   100, train loss 0.142977, train error 1.25,  test loss 2.285139, test error 52.78
# Epoch   200, train loss 0.014330, train error 0.00,  test loss 3.376718, test error 53.15
# Epoch   300, train loss 0.006390, train error 0.00,  test loss 3.823087, test error 53.42
# Epoch   400, train loss 0.003891, train error 0.00,  test loss 4.089475, test error 53.30
# Epoch   500, train loss 0.002739, train error 0.00,  test loss 4.285084, test error 53.28
# Epoch   600, train loss 0.002082, train error 0.00,  test loss 4.437351, test error 53.22
# Epoch   700, train loss 0.001667, train error 0.00,  test loss 4.562289, test error 53.15
# Epoch   800, train loss 0.001381, train error 0.00,  test loss 4.667442, test error 53.15
# Epoch   900, train loss 0.001173, train error 0.00,  test loss 4.758577, test error 53.25
# Training model with 100 hidden variables
# Epoch     0, train loss 2.015026, train error 75.55,  test loss 1.955462, test error 75.28
# Epoch   100, train loss 0.095424, train error 0.20,  test loss 2.178526, test error 50.33
# Epoch   200, train loss 0.012620, train error 0.00,  test loss 3.057364, test error 50.72
# Epoch   300, train loss 0.005779, train error 0.00,  test loss 3.417657, test error 50.85
# Epoch   400, train loss 0.003586, train error 0.00,  test loss 3.644373, test error 50.95
# Epoch   500, train loss 0.002547, train error 0.00,  test loss 3.807584, test error 51.05
# Epoch   600, train loss 0.001948, train error 0.00,  test loss 3.936660, test error 51.12
# Epoch   700, train loss 0.001564, train error 0.00,  test loss 4.041710, test error 50.92
# Epoch   800, train loss 0.001298, train error 0.00,  test loss 4.131940, test error 50.88
# Epoch   900, train loss 0.001105, train error 0.00,  test loss 4.210299, test error 50.92
# Training model with 120 hidden variables
# Epoch     0, train loss 1.963474, train error 72.10,  test loss 1.881119, test error 73.22
# Epoch   100, train loss 0.049236, train error 0.00,  test loss 2.279735, test error 50.33
# Epoch   200, train loss 0.009412, train error 0.00,  test loss 2.917995, test error 50.72
# Epoch   300, train loss 0.004658, train error 0.00,  test loss 3.204604, test error 50.88
# Epoch   400, train loss 0.002986, train error 0.00,  test loss 3.389843, test error 51.08
# Epoch   500, train loss 0.002157, train error 0.00,  test loss 3.527580, test error 51.05
# Epoch   600, train loss 0.001668, train error 0.00,  test loss 3.637688, test error 51.05
# Epoch   700, train loss 0.001349, train error 0.00,  test loss 3.728752, test error 51.00
# Epoch   800, train loss 0.001126, train error 0.00,  test loss 3.806112, test error 50.97
# Epoch   900, train loss 0.000963, train error 0.00,  test loss 3.872671, test error 51.03
# Training model with 140 hidden variables
# Epoch     0, train loss 1.961547, train error 71.72,  test loss 1.878528, test error 73.25
# Epoch   100, train loss 0.036855, train error 0.00,  test loss 2.217246, test error 50.75
# Epoch   200, train loss 0.008143, train error 0.00,  test loss 2.701473, test error 50.58
# Epoch   300, train loss 0.004164, train error 0.00,  test loss 2.932584, test error 50.42
# Epoch   400, train loss 0.002702, train error 0.00,  test loss 3.083157, test error 50.35
# Epoch   500, train loss 0.001965, train error 0.00,  test loss 3.196841, test error 50.28
# Epoch   600, train loss 0.001528, train error 0.00,  test loss 3.287187, test error 50.25
# Epoch   700, train loss 0.001240, train error 0.00,  test loss 3.362356, test error 50.20
# Epoch   800, train loss 0.001039, train error 0.00,  test loss 3.426611, test error 50.22
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.482435, test error 50.17
# Training model with 160 hidden variables
# Epoch     0, train loss 1.974952, train error 72.40,  test loss 1.881683, test error 73.60
# Epoch   100, train loss 0.028759, train error 0.00,  test loss 2.163360, test error 49.08
# Epoch   200, train loss 0.007133, train error 0.00,  test loss 2.591402, test error 49.28
# Epoch   300, train loss 0.003736, train error 0.00,  test loss 2.801713, test error 49.65
# Epoch   400, train loss 0.002457, train error 0.00,  test loss 2.941809, test error 49.53
# Epoch   500, train loss 0.001798, train error 0.00,  test loss 3.043946, test error 49.58
# Epoch   600, train loss 0.001405, train error 0.00,  test loss 3.126024, test error 49.62
# Epoch   700, train loss 0.001144, train error 0.00,  test loss 3.196398, test error 49.60
# Epoch   800, train loss 0.000961, train error 0.00,  test loss 3.254764, test error 49.53
# Epoch   900, train loss 0.000825, train error 0.00,  test loss 3.307380, test error 49.58
# Training model with 180 hidden variables
# Epoch     0, train loss 1.916461, train error 69.60,  test loss 1.847724, test error 71.18
# Epoch   100, train loss 0.023473, train error 0.00,  test loss 2.059149, test error 48.17
# Epoch   200, train loss 0.006452, train error 0.00,  test loss 2.416447, test error 48.50
# Epoch   300, train loss 0.003468, train error 0.00,  test loss 2.590144, test error 48.53
# Epoch   400, train loss 0.002295, train error 0.00,  test loss 2.709436, test error 48.50
# Epoch   500, train loss 0.001690, train error 0.00,  test loss 2.799379, test error 48.65
# Epoch   600, train loss 0.001325, train error 0.00,  test loss 2.872032, test error 48.83
# Epoch   700, train loss 0.001082, train error 0.00,  test loss 2.932510, test error 48.72
# Epoch   800, train loss 0.000910, train error 0.00,  test loss 2.983970, test error 48.78
# Epoch   900, train loss 0.000783, train error 0.00,  test loss 3.029270, test error 48.75
# Training model with 200 hidden variables
# Epoch     0, train loss 1.931266, train error 69.55,  test loss 1.830479, test error 69.55
# Epoch   100, train loss 0.021335, train error 0.00,  test loss 2.052878, test error 48.95
# Epoch   200, train loss 0.006125, train error 0.00,  test loss 2.388149, test error 49.25
# Epoch   300, train loss 0.003327, train error 0.00,  test loss 2.556872, test error 48.92
# Epoch   400, train loss 0.002219, train error 0.00,  test loss 2.670518, test error 49.20
# Epoch   500, train loss 0.001639, train error 0.00,  test loss 2.755799, test error 49.35
# Epoch   600, train loss 0.001288, train error 0.00,  test loss 2.824731, test error 49.20
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.882423, test error 49.17
# Epoch   800, train loss 0.000887, train error 0.00,  test loss 2.931439, test error 49.25
# Epoch   900, train loss 0.000764, train error 0.00,  test loss 2.974536, test error 49.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.911484, train error 70.28,  test loss 1.836185, test error 71.15
# Epoch   100, train loss 0.016781, train error 0.00,  test loss 1.927382, test error 47.72
# Epoch   200, train loss 0.005313, train error 0.00,  test loss 2.186513, test error 47.47
# Epoch   300, train loss 0.002954, train error 0.00,  test loss 2.321245, test error 47.53
# Epoch   400, train loss 0.001996, train error 0.00,  test loss 2.415100, test error 47.55
# Epoch   500, train loss 0.001486, train error 0.00,  test loss 2.485113, test error 47.58
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.542583, test error 47.60
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.591219, test error 47.47
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.631882, test error 47.50
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.668539, test error 47.65
# Training model with 300 hidden variables
# Epoch     0, train loss 1.923281, train error 67.72,  test loss 1.836857, test error 71.05
# Epoch   100, train loss 0.014486, train error 0.00,  test loss 1.913131, test error 47.42
# Epoch   200, train loss 0.004810, train error 0.00,  test loss 2.141802, test error 47.40
# Epoch   300, train loss 0.002730, train error 0.00,  test loss 2.267183, test error 47.38
# Epoch   400, train loss 0.001857, train error 0.00,  test loss 2.352429, test error 47.38
# Epoch   500, train loss 0.001389, train error 0.00,  test loss 2.418115, test error 47.58
# Epoch   600, train loss 0.001100, train error 0.00,  test loss 2.470692, test error 47.62
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.515730, test error 47.53
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.553730, test error 47.53
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.588080, test error 47.60
# Training model with 400 hidden variables
# Epoch     0, train loss 1.859870, train error 64.72,  test loss 1.769862, test error 66.95
# Epoch   100, train loss 0.011756, train error 0.00,  test loss 1.820088, test error 47.67
# Epoch   200, train loss 0.004166, train error 0.00,  test loss 2.003647, test error 47.53
# Epoch   300, train loss 0.002414, train error 0.00,  test loss 2.106606, test error 47.50
# Epoch   400, train loss 0.001663, train error 0.00,  test loss 2.177142, test error 47.55
# Epoch   500, train loss 0.001254, train error 0.00,  test loss 2.232467, test error 47.62
# Epoch   600, train loss 0.000998, train error 0.00,  test loss 2.276750, test error 47.55
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.314237, test error 47.60
# Epoch   800, train loss 0.000700, train error 0.00,  test loss 2.346388, test error 47.53
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.374808, test error 47.55

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
